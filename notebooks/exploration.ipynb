# %% [markdown]
# # Lateral Project - Exploration Notebook
#
# This notebook is for exploring the lane detection and 3D object recognition capabilities.

# %%
import sys
sys.path.append('../src')

from lateral_sota.ultrafastLaneDetector import UltrafastLaneDetector
import matplotlib.pyplot as plt

# %%
# Load an image and run lane detection
# image_path = '../data/kitti/training/image_2/000000.png'
# detector = UltrafastLaneDetector('../weights/lane_detection/tusimple_res18.pth', model_type='TUSIMPLE')
# lanes = detector.detect_lanes(image_path)

# %%
# Visualize results
# plt.imshow(lanes)
# plt.show()
